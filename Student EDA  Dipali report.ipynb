# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
from six.moves import urllib
import os

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df = pd.read_csv("student.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df["Mean Score"] = ((df["math score"]+df["reading score"]+df["writing score"])/3).round()
df.head(20)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df["gender"].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %% [raw]
# Report 1:
#     Female is more than male in class

# %% [markdown]
# # Analysing Gender and Race

# %% [raw]
# Label Encoding

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder

lc = LabelEncoder()
df["gender"] = lc.fit_transform(df["gender"])
df["race/ethnicity"] = lc.fit_transform(df["race/ethnicity"])
df["parental level of education"] = lc.fit_transform(df["parental level of education"])
df["lunch"] = lc.fit_transform(df["lunch"])
df["test preparation course"] = lc.fit_transform(df["test preparation course"])
df.head(20)
# Out:
#     gender  race/ethnicity  parental level of education  lunch  \
# 0        0               1                            1      1
# 1        0               2                            4      1
# 2        0               1                            3      1
# 3        1               0                            0      0
# 4        1               2                            4      1
# 5        0               1                            0      1
# 6        0               1                            4      1
# 7        1               1                            4      0
# 8        1               3                            2      0
# 9        0               1                            2      0
# 10       1               2                            0      1
# 11       1               3                            0      1
# 12       0               1                            2      1
# 13       1               0                            4      1
# ...

# %% [markdown]
# # Analysing gender and race

# %%
sns.countplot(x=df["gender"], hue=df["race/ethnicity"])
plt.show()

# %% [raw]
# Report 2 . There are more female in class (mostly group C)

# %% [markdown]
# # Analysing test preparatin Course

# %%
df["test preparation course"].value_counts()
# Out:
# test preparation course
# 1    642
# 0    358
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="test preparation course",y="Mean Score",data =df)
plt.show()

# %% [raw]
# Report 3 .Student who ahve not completed course score less than student who have completed course . thus student should focus on completeing course

# %% [markdown]
# # Analysing Lunch

# %%
sns.barplot(x = df["lunch"],y= df["Mean Score"],data = df)
# Out:
# <Axes: xlabel='lunch', ylabel='Mean Score'>

# %% [raw]
# Report 4. Student who get standard lunch are performing better than student who get free lunch

# %% [markdown]
# # Analysing Parental level of eductaion

# %%
sns.barplot(x="parental level of education",y="Mean Score",data =df)
# Out:
# <Axes: xlabel='parental level of education', ylabel='Mean Score'>

# %% [raw]
# Report 5 . Students of  Parent who are having master degree perform better than all group and student of parent who have only completed High school perform worst

# %% [markdown]
# # Summary of Report
# 1. Female Students is more than male Students in all group
# 2. There are more female in all group (mostly group C)
# 3. Student who have not completed course score less than student who have completed course ,thus student should focus on completeing course
# 4. Student who get standard lunch are performing better than student who get free lunch
# 5. Students of  Parent who are having master degree perform better than all group and student of parent who have only completed High school perform worst
